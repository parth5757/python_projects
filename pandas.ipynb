# %% [markdown]
# <a href="https://colab.research.google.com/github/parth5757/python_projects/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hi Parth

# %%
# !pip install numpy
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name": ['parth', 'het', 'zeel', 'jay'],
    "marks": [89, 56, 95, 98],
    "city": ['bavla', 'bavla', 'vasna', 'vasna']
}

# %% [markdown]
# Make an dictionary into data frame

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#     name  marks   city
# 0  parth     89  bavla
# 1    het     56  bavla
# 2   zeel     95  vasna
# 3    jay     98  vasna

# %% [markdown]
# Dataframe to csv

# %%
# df.to_csv('1.csv')
df.to_csv('2.csv', index=False)

# %% [markdown]
# Taking an row from last

# %%
df.tail(2)
# Out:
#    name  marks   city
# 2  zeel     95  vasna
# 3   jay     98  vasna

# %% [markdown]
# TO describe most of thing in dataframes

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   84.500000
# std    19.364917
# min    56.000000
# 25%    80.750000
# 50%    92.000000
# 75%    95.750000
# max    98.000000
